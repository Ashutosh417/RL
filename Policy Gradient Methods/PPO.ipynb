# %%
import numpy as np 
import matplotlib.pyplot as plt 

import torch 
import torch.nn as nn
from torch.optim import Adam
from torch.distributions import Categorical

import gymnasium as gym

# %%
env = gym.make("LunarLander-v3",
                render_mode='rgb_array')

# %%
obs,_ = env.reset()
img = env.render()
plt.imshow(img)

# %%
class Actor(nn.Module):
    def __init__(self, n_states, n_actions):
        super(Actor,self).__init__()

        self.fc1 = nn.Sequential(
            nn.Linear(n_states,256),
            nn.ReLU(),
            nn.Linear(256,128),
            nn.ReLU(),
            nn.Linear(128,n_actions),
            nn.Softmax(dim=-1)
        )


    def forward(self, x):
        return self.fc1(x)


class Critic(nn.Module):
    def __init__(self, n_states):
        super(Critic,self).__init__()

        self.fc2 = nn.Sequential(
            nn.Linear(n_states,128),
            nn.ReLU(),
            nn.Linear(128,64),
            nn.ReLU(),
            nn.Linear(64,1)
        )


    def forward(self, x):
        return self.fc2(x)

# %%
class RLAgent:
    def __init__(self,env, n_states, n_actions, n_episodes, gamma=0.99):
        self.env = env
        self.n_states = n_states
        self.n_actions = n_actions
        self.n_episodes = n_episodes

        self.gamma = gamma
        self.lr = 1e-3
        self.epsilon = 0.2
        self.k = 10
        self.rollout_steps = 2048
        self.entropy_coeff = 0.01


        self.reward_per_10epi = []
        self.epino_forplot = []
        self.all_rewards=[]
        self.dones = []

        self.rewards = []
        self.log_prob = []
        self.old_log_prob = []

        self.states = []
        self.actions = []
        self.Rewards = []
        self.entropy = []

        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

        self.Actor = Actor(self.n_states,self.n_actions)
        self.Actor.to(self.device)
        self.Critic = Critic(self.n_states)
        self.Critic.to(self.device)
        #self.optim = Adam(
        #    list(self.Actor.parameters()) + list(self.Critic.parameters()),
        #    lr=self.lr)
        self.optim = Adam([
            {'params': self.Actor.parameters(), 'lr': 3e-4},
            {'params': self.Critic.parameters(), 'lr': 1e-3}])
              # Tried different lr to overcome plateau at around -50

        self.scheduler = torch.optim.lr_scheduler.LinearLR(
            self.optim, start_factor=1.0, end_factor=0.1, total_iters=n_episodes)




    def choose_action(self,state):
        state = torch.tensor(state,dtype=torch.float32).unsqueeze(0).to(self.device)
        # PYTORCH NETWORKS ALWAYS TAKE TENSORS ONLY AS INPUT
        action_prob = self.Actor(state)

        distr = Categorical(action_prob)
        action = distr.sample()
        log_prob = distr.log_prob(action)
        self.log_prob.append(log_prob)
        entropy = distr.entropy()
        self.entropy.append(entropy)

        self.old_log_prob.append(log_prob.detach())  # Freezing old_log_prob

        return action.item()

 #GENERALIZED ADVANTAGE ESTIMATION (Instead of montecarlo return we use TD(lambda) return)
    def compute_gae(self, rewards, values, dones,last_state, lam=0.95):
        advantages = []
        gae = 0
        with torch.no_grad():
             last_state_t = torch.tensor(last_state, dtype=torch.float32).unsqueeze(0).to(self.device)
             next_value = self.Critic(last_state_t).squeeze().item() * (1 - dones[-1])
        values_ext = values + [next_value]

        for t in reversed(range(len(rewards))):
            delta = (rewards[t]
                     + self.gamma * values_ext[t+1] * (1 - dones[t])
                     - values_ext[t])
            gae = delta + self.gamma * lam * (1 - dones[t]) * gae
            advantages.insert(0, gae)

        advantages = torch.tensor(advantages, dtype=torch.float32)
        returns = advantages + torch.tensor(values, dtype=torch.float32)
        return advantages, returns


    def compute_loss(self,states,last_state,rewards,dones):


        states = torch.tensor(np.array(states), dtype=torch.float32).to(self.device)
        # PYTORCH NETWORKS ALWAYS TAKE TENSORS ONLY AS INPUT
        actions = torch.tensor(self.actions, dtype=torch.long).to(self.device)
        old_log_probs = torch.stack(self.old_log_prob).squeeze().to(self.device) # Before stack — list of tensors
                                                                #[tensor(1.38), tensor(1.25), tensor(1.41)]
                                                                # After stack — single tensor
                                                                #tensor([1.38, 1.25, 1.41])


        with torch.no_grad():  #computing advantage once outside epoch wala loop
            V = self.Critic(states).squeeze(-1).cpu().tolist() 
        
        A, returns = self.compute_gae(rewards, V, dones,last_state)
 
        G = returns.to(self.device)
        A = A.to(self.device)

        for _ in range(self.k):

            A_norm = ((A - A.mean()) / (A.std() + 1e-8)).to(self.device)

            action_probs = self.Actor(states)
            dist = Categorical(action_probs)
            new_log_probs = dist.log_prob(actions)
            entropy = dist.entropy().mean()

            new_V = self.Critic(states).squeeze(-1)


            ratio = (new_log_probs - old_log_probs).exp()

            clipped = torch.clamp(ratio, 1 - self.epsilon, 1 + self.epsilon)
            Actorloss = -torch.min(ratio * A_norm.detach(), clipped * A_norm.detach()).mean() # .detach() to prevent flow of grad through adv into critic twice
                                                                                    ## A->V-> critic weightd meaning actor loss le critic weights lai change garthiyo if there was no detach
            Criticloss = ((G - new_V)**2).mean()    

            loss = Actorloss + 0.5 * Criticloss - self.entropy_coeff * entropy # - sign means we want to max entropy)

            self.optim.zero_grad()
            loss.backward()
            nn.utils.clip_grad_norm_(
                list(self.Actor.parameters()) + list(self.Critic.parameters()),
                max_norm = 0.5
            )
            self.optim.step() 
        self.scheduler.step()                                               
        del self.log_prob[:]
        del self.entropy[:]
        del self.old_log_prob[:]



    def train(self):
        
        for episode in range(self.n_episodes):
    
            self.states = []
            self.actions = []
            self.rewards = []
            self.log_prob = []
            self.old_log_prob = []
            self.entropy = []
            self.dones = []
            
            steps_collected = 0

            while steps_collected < self.rollout_steps: #collecting 2048 trajectories
                state, _ = self.env.reset()
                done = False
                total_reward = 0



                while not done:
                    action = self.choose_action(state)
                    next_state, reward, term, trunc, _ = self.env.step(action)
                    done = term or trunc

                    self.states.append(state)
                    self.rewards.append(reward)
                    self.actions.append(action)
                    self.dones.append(1.0 if term else 0.0)


                    total_reward += reward

                    last_state = state

                    state = next_state

                    steps_collected += 1

                    if steps_collected == self.rollout_steps:
                        break

                if done:
                    self.all_rewards.append(total_reward)
        
            self.compute_loss(self.states,last_state,self.rewards,self.dones)

            self.entropy_coeff = max(self.entropy_coeff * 0.995, 0.0001)

            
            if episode % 10 == 0:
                self.epino_forplot.append(episode)
            
                if len(self.all_rewards) > 0:
                    avg = np.mean(self.all_rewards[-10:]) 
                    last_completed = self.all_rewards[-1]
                else:
                    avg = 0
                    last_completed = 0
                    
                print(f"Update {episode} | Avg_Reward (last 10): {avg:.2f} | Last_Completed_Reward: {last_completed:.2f}")

                                    
    def plot(self):
        moving_avg = np.convolve(self.all_rewards, np.ones(100)/100, mode='valid')
        fig, ax = plt.subplots(figsize = (8,6))

        x_axis = np.arange(99, len(self.all_rewards)) # creates array from 99 to total episode length
        #ax.plot(self.epino_forplot,self.reward_per_10epi,color='blue',label="Reward Per 10 Episodes")
        ax.plot(x_axis, moving_avg, color='red', label="100-Episode Moving Average")

        #X = 0 on the graph technically represents Episode 100, X = 1 represents Episode 101, and so on.

        ax.set_xlabel("Episode")
        ax.set_ylabel("Reward")
        ax.set_title("PPO Training Progress")
        ax.legend(loc="upper left")
        plt.show()

# %%
Agent = RLAgent(env, 8, 4, 2050)

# %%
Agent.train()
# Out:
# Update 0 | Avg_Reward (last 10): -177.92 | Last_Completed_Reward: -205.31
# Update 10 | Avg_Reward (last 10): -104.24 | Last_Completed_Reward: -144.85
# Update 20 | Avg_Reward (last 10): -149.84 | Last_Completed_Reward: 18.65
# Update 30 | Avg_Reward (last 10): -84.64 | Last_Completed_Reward: -57.21
# Update 40 | Avg_Reward (last 10): -36.26 | Last_Completed_Reward: 84.44
# Update 50 | Avg_Reward (last 10): -84.03 | Last_Completed_Reward: -104.68
# Update 60 | Avg_Reward (last 10): -51.09 | Last_Completed_Reward: -49.03
# Update 70 | Avg_Reward (last 10): -56.43 | Last_Completed_Reward: -61.24
# Update 80 | Avg_Reward (last 10): -97.87 | Last_Completed_Reward: -115.58
# Update 90 | Avg_Reward (last 10): -22.95 | Last_Completed_Reward: -84.56
# Update 100 | Avg_Reward (last 10): -51.14 | Last_Completed_Reward: -64.42
# Update 110 | Avg_Reward (last 10): -49.62 | Last_Completed_Reward: -93.90
# Update 120 | Avg_Reward (last 10): -46.75 | Last_Completed_Reward: 6.40
# Update 130 | Avg_Reward (last 10): -40.59 | Last_Completed_Reward: -72.18
# Update 140 | Avg_Reward (last 10): -26.22 | Last_Completed_Reward: 36.44
# Update 150 | Avg_Reward (last 10): 23.73 | Last_Completed_Reward: 26.62
# Update 160 | Avg_Reward (last 10): -73.51 | Last_Completed_Reward: -115.14
# Update 170 | Avg_Reward (last 10): -52.51 | Last_Completed_Reward: -47.11
# Update 180 | Avg_Reward (last 10): -94.03 | Last_Completed_Reward: -81.08
# Update 190 | Avg_Reward (last 10): 31.94 | Last_Completed_Reward: -12.84
# Update 200 | Avg_Reward (last 10): 38.14 | Last_Completed_Reward: -168.62
# Update 210 | Avg_Reward (last 10): 80.85 | Last_Completed_Reward: 73.58
# Update 220 | Avg_Reward (last 10): 53.24 | Last_Completed_Reward: -53.17
# Update 230 | Avg_Reward (last 10): 5.56 | Last_Completed_Reward: 109.96
# Update 240 | Avg_Reward (last 10): -54.39 | Last_Completed_Reward: -87.93
# Update 250 | Avg_Reward (last 10): -57.77 | Last_Completed_Reward: -87.02
# Update 260 | Avg_Reward (last 10): -16.37 | Last_Completed_Reward: -99.02
# Update 270 | Avg_Reward (last 10): 34.60 | Last_Completed_Reward: 79.66
# Update 280 | Avg_Reward (last 10): 69.10 | Last_Completed_Reward: 185.03
# Update 290 | Avg_Reward (last 10): 33.87 | Last_Completed_Reward: -98.12
# Update 300 | Avg_Reward (last 10): 71.04 | Last_Completed_Reward: 82.05
# Update 310 | Avg_Reward (last 10): -10.48 | Last_Completed_Reward: 78.69
# Update 320 | Avg_Reward (last 10): 43.12 | Last_Completed_Reward: 100.69
# Update 330 | Avg_Reward (last 10): 84.95 | Last_Completed_Reward: 105.01
# Update 340 | Avg_Reward (last 10): 1.85 | Last_Completed_Reward: -76.86
# Update 350 | Avg_Reward (last 10): 39.14 | Last_Completed_Reward: 155.56
# Update 360 | Avg_Reward (last 10): 50.61 | Last_Completed_Reward: 93.11
# Update 370 | Avg_Reward (last 10): 24.22 | Last_Completed_Reward: -137.63
# Update 380 | Avg_Reward (last 10): 40.62 | Last_Completed_Reward: -18.46
# Update 390 | Avg_Reward (last 10): -28.77 | Last_Completed_Reward: -110.34
# Update 400 | Avg_Reward (last 10): 19.14 | Last_Completed_Reward: -78.94
# Update 410 | Avg_Reward (last 10): -15.21 | Last_Completed_Reward: -228.95
# Update 420 | Avg_Reward (last 10): 24.59 | Last_Completed_Reward: -180.97
# Update 430 | Avg_Reward (last 10): 44.86 | Last_Completed_Reward: 14.43
# Update 440 | Avg_Reward (last 10): 26.17 | Last_Completed_Reward: -97.84
# Update 450 | Avg_Reward (last 10): 52.46 | Last_Completed_Reward: 88.36
# Update 460 | Avg_Reward (last 10): -6.76 | Last_Completed_Reward: 67.20
# Update 470 | Avg_Reward (last 10): 56.87 | Last_Completed_Reward: 93.08
# Update 480 | Avg_Reward (last 10): 45.33 | Last_Completed_Reward: -91.28
# Update 490 | Avg_Reward (last 10): 10.34 | Last_Completed_Reward: -170.85
# Update 500 | Avg_Reward (last 10): -19.20 | Last_Completed_Reward: 46.65
# Update 510 | Avg_Reward (last 10): 38.15 | Last_Completed_Reward: 124.27
# Update 520 | Avg_Reward (last 10): 69.30 | Last_Completed_Reward: -26.39
# Update 530 | Avg_Reward (last 10): 36.00 | Last_Completed_Reward: 98.29
# Update 540 | Avg_Reward (last 10): 29.26 | Last_Completed_Reward: -92.52
# Update 550 | Avg_Reward (last 10): 6.81 | Last_Completed_Reward: -77.44
# Update 560 | Avg_Reward (last 10): 44.83 | Last_Completed_Reward: 73.18
# Update 570 | Avg_Reward (last 10): 30.57 | Last_Completed_Reward: 63.80
# Update 580 | Avg_Reward (last 10): 68.40 | Last_Completed_Reward: 113.69
# Update 590 | Avg_Reward (last 10): 74.95 | Last_Completed_Reward: 162.34
# Update 600 | Avg_Reward (last 10): 65.35 | Last_Completed_Reward: -42.01
# Update 610 | Avg_Reward (last 10): 141.08 | Last_Completed_Reward: 14.10
# Update 620 | Avg_Reward (last 10): 84.49 | Last_Completed_Reward: 106.30
# Update 630 | Avg_Reward (last 10): 150.42 | Last_Completed_Reward: 24.30
# Update 640 | Avg_Reward (last 10): 101.18 | Last_Completed_Reward: 185.63
# Update 650 | Avg_Reward (last 10): 118.75 | Last_Completed_Reward: 210.25
# Update 660 | Avg_Reward (last 10): 61.19 | Last_Completed_Reward: -35.34
# Update 670 | Avg_Reward (last 10): 53.37 | Last_Completed_Reward: 53.79
# Update 680 | Avg_Reward (last 10): 96.44 | Last_Completed_Reward: 213.02
# Update 690 | Avg_Reward (last 10): 93.31 | Last_Completed_Reward: 215.35
# Update 700 | Avg_Reward (last 10): 149.66 | Last_Completed_Reward: 238.63
# Update 710 | Avg_Reward (last 10): 91.64 | Last_Completed_Reward: 203.81
# Update 720 | Avg_Reward (last 10): 134.00 | Last_Completed_Reward: 182.09
# Update 730 | Avg_Reward (last 10): 112.38 | Last_Completed_Reward: 211.99
# Update 740 | Avg_Reward (last 10): 160.95 | Last_Completed_Reward: 240.35
# Update 750 | Avg_Reward (last 10): 164.35 | Last_Completed_Reward: 173.50
# Update 760 | Avg_Reward (last 10): 96.90 | Last_Completed_Reward: 118.38
# Update 770 | Avg_Reward (last 10): 134.94 | Last_Completed_Reward: 119.37
# Update 780 | Avg_Reward (last 10): 116.01 | Last_Completed_Reward: 188.39
# Update 790 | Avg_Reward (last 10): 94.19 | Last_Completed_Reward: 146.49
# Update 800 | Avg_Reward (last 10): 146.74 | Last_Completed_Reward: -33.26
# Update 810 | Avg_Reward (last 10): 206.91 | Last_Completed_Reward: 235.13
# Update 820 | Avg_Reward (last 10): 105.64 | Last_Completed_Reward: 191.22
# Update 830 | Avg_Reward (last 10): 185.50 | Last_Completed_Reward: 215.51
# Update 840 | Avg_Reward (last 10): 170.48 | Last_Completed_Reward: 197.12
# Update 850 | Avg_Reward (last 10): 138.85 | Last_Completed_Reward: 238.19
# Update 860 | Avg_Reward (last 10): 103.66 | Last_Completed_Reward: 239.15
# Update 870 | Avg_Reward (last 10): 139.40 | Last_Completed_Reward: 10.96
# Update 880 | Avg_Reward (last 10): 128.74 | Last_Completed_Reward: 245.85
# Update 890 | Avg_Reward (last 10): 175.45 | Last_Completed_Reward: 231.66
# Update 900 | Avg_Reward (last 10): 203.88 | Last_Completed_Reward: 271.03
# Update 910 | Avg_Reward (last 10): 149.67 | Last_Completed_Reward: 141.27
# Update 920 | Avg_Reward (last 10): 150.91 | Last_Completed_Reward: 5.51
# Update 930 | Avg_Reward (last 10): 151.53 | Last_Completed_Reward: 264.22
# Update 940 | Avg_Reward (last 10): 175.48 | Last_Completed_Reward: -32.74
# Update 950 | Avg_Reward (last 10): 208.55 | Last_Completed_Reward: 255.94
# Update 960 | Avg_Reward (last 10): 175.25 | Last_Completed_Reward: 227.76
# Update 970 | Avg_Reward (last 10): 223.34 | Last_Completed_Reward: 271.08
# Update 980 | Avg_Reward (last 10): 208.49 | Last_Completed_Reward: 266.33
# Update 990 | Avg_Reward (last 10): 142.53 | Last_Completed_Reward: 259.08
# Update 1000 | Avg_Reward (last 10): 237.50 | Last_Completed_Reward: 290.42
# Update 1010 | Avg_Reward (last 10): 198.85 | Last_Completed_Reward: 270.93
# Update 1020 | Avg_Reward (last 10): 181.76 | Last_Completed_Reward: 104.90
# Update 1030 | Avg_Reward (last 10): 145.25 | Last_Completed_Reward: 274.43
# Update 1040 | Avg_Reward (last 10): 157.97 | Last_Completed_Reward: 240.39
# Update 1050 | Avg_Reward (last 10): 134.95 | Last_Completed_Reward: 1.16
# Update 1060 | Avg_Reward (last 10): 153.92 | Last_Completed_Reward: 271.20
# Update 1070 | Avg_Reward (last 10): 174.76 | Last_Completed_Reward: 237.42
# Update 1080 | Avg_Reward (last 10): 214.06 | Last_Completed_Reward: 260.95
# Update 1090 | Avg_Reward (last 10): 231.95 | Last_Completed_Reward: 242.30
# Update 1100 | Avg_Reward (last 10): 203.79 | Last_Completed_Reward: 259.15
# Update 1110 | Avg_Reward (last 10): 223.36 | Last_Completed_Reward: 252.89
# Update 1120 | Avg_Reward (last 10): 215.95 | Last_Completed_Reward: 262.45
# Update 1130 | Avg_Reward (last 10): 135.06 | Last_Completed_Reward: 235.51
# Update 1140 | Avg_Reward (last 10): 204.83 | Last_Completed_Reward: 230.53
# Update 1150 | Avg_Reward (last 10): 207.05 | Last_Completed_Reward: 247.03
# Update 1160 | Avg_Reward (last 10): 172.34 | Last_Completed_Reward: 248.43
# Update 1170 | Avg_Reward (last 10): 204.43 | Last_Completed_Reward: 5.54
# Update 1180 | Avg_Reward (last 10): 262.22 | Last_Completed_Reward: 248.51
# Update 1190 | Avg_Reward (last 10): 215.37 | Last_Completed_Reward: 268.33
# Update 1200 | Avg_Reward (last 10): 214.57 | Last_Completed_Reward: -16.36
# Update 1210 | Avg_Reward (last 10): 235.42 | Last_Completed_Reward: 293.66
# Update 1220 | Avg_Reward (last 10): 207.22 | Last_Completed_Reward: 266.50
# Update 1230 | Avg_Reward (last 10): 245.34 | Last_Completed_Reward: 242.10
# Update 1240 | Avg_Reward (last 10): 256.73 | Last_Completed_Reward: 283.97
# Update 1250 | Avg_Reward (last 10): 233.50 | Last_Completed_Reward: 137.77
# Update 1260 | Avg_Reward (last 10): 190.41 | Last_Completed_Reward: 268.30
# Update 1270 | Avg_Reward (last 10): 215.64 | Last_Completed_Reward: 279.58
# Update 1280 | Avg_Reward (last 10): 215.66 | Last_Completed_Reward: 243.81
# Update 1290 | Avg_Reward (last 10): 217.79 | Last_Completed_Reward: 151.74
# Update 1300 | Avg_Reward (last 10): 235.73 | Last_Completed_Reward: 273.65
# Update 1310 | Avg_Reward (last 10): 274.97 | Last_Completed_Reward: 303.72
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 Agent.train()
#
# Cell In[41], line 164, in RLAgent.train(self)
#     160
#     161
#     162
#     163                 while not done:
# --> 164                     action = self.choose_action(state)
#     165                     next_state, reward, term, trunc, _ = self.env.step(action)
#     166                     done = term or trunc
#     167
#
# Cell In[41], line 55, in RLAgent.choose_action(self, state)
#      51         state = torch.tensor(state,dtype=torch.float32).unsqueeze(0).to(self.device)
#      52         # PYTORCH NETWORKS ALWAYS TAKE TENSORS ONLY AS INPUT
#      53         action_prob = self.Actor(state)
#      54
# ---> 55         distr = Categorical(action_prob)
#      56         action = distr.sample()
#      57         log_prob = distr.log_prob(action)
#      58         self.log_prob.append(log_prob)
#
# File c:\Users\Ashutosh Thapa\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\distributions\categorical.py:85, in Categorical.__init__(self, probs, logits, validate_args)
#      81 batch_shape = (
#      82     self._param.size()[:-1] if self._param.ndimension() > 1 else torch.Size()
#      83 )
#      84 # pyrefly: ignore [bad-argument-type]
# ---> 85 super().__init__(batch_shape, validate_args=validate_args)
#
# File c:\Users\Ashutosh Thapa\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\distributions\distribution.py:76, in Distribution.__init__(self, batch_shape, event_shape, validate_args)
#      74         value = getattr(self, param)
#      75         valid = constraint.check(value)
# ---> 76         if not torch._is_all_true(valid):
#      77             raise ValueError(
#      78                 f"Expected parameter {param} "
#      79                 f"({type(value).__name__} of shape {tuple(value.shape)}) "
#    (...)     82                 f"but found invalid values:\n{value}"
#      83             )
#      84 super().__init__()
#
# KeyboardInterrupt:

# %%
Agent.plot()

# %%
torch.save({
    'actor': Agent.Actor.state_dict(),
    'critic': Agent.Critic.state_dict(),
    'optimizer': Agent.optim.state_dict(),
}, 'ppo_save.pth')

# %%
checkpoint = torch.load('ppo_save.pth')
Agent.Actor.load_state_dict(checkpoint['actor'])
Agent.Critic.load_state_dict(checkpoint['critic'])
Agent.optim.load_state_dict(checkpoint['optimizer'])

Agent.Actor.eval()
Agent.Critic.eval()
# Out:
# Critic(
#   (fc2): Sequential(
#     (0): Linear(in_features=8, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=64, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=64, out_features=1, bias=True)
#   )
# )

# %%
env = gym.make("LunarLander-v3",render_mode='human')

for i in range(3):
    done = False
    total_reward = 0
    state,_ = env.reset()

    while not done:

        action = Agent.choose_action(state)
        next_state, reward, term, trunc, _ = env.step(action)
        done = term or trunc
        state = next_state
        total_reward += reward

    print(f'Total Reward This Episode: {total_reward}')
env.close()
# Out:
# Total Reward This Episode: 302.1982749528117
# Total Reward This Episode: 157.97013787437322
# Total Reward This Episode: 251.00705765272212
